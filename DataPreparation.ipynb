# %%
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

from collections import defaultdict
from scipy.stats.stats import pearsonr

# %%
df=pd.read_csv("datatraining.csv", sep=";")

# %%
df.head()
# Out:
#    id            date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 0   1  04/02/15 17:51        23.18   27.2720  426.0  721.25       0.004793
# 1   2  04/02/15 17:51        23.15   27.2675  429.5  714.00       0.004783
# 2   3  04/02/15 17:53        23.15   27.2450  426.0  713.50       0.004779
# 3   4  04/02/15 17:54        23.15   27.2000  426.0  708.25       0.004772
# 4   5  04/02/15 17:55        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# Temperature      0
# Humidity         0
# Light            0
# CO2              0
# HumidityRatio    0
# Occupancy        0
# dtype: int64

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col2 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col5 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row1_col3 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row1_col4 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row1_col6 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row2_col0 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row2_col1 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row2_col3 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row2_col4 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row2_col5 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row2_col6 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row3_col0 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row3_col1 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row3_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row3_col4 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row3_col5 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row3_col6 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row4_col0 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row4_col1 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row4_col2 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row4_col3 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row4_col5 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row4_col6 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row5_col0 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row5_col1 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row5_col2 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row5_col3 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row5_col4 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row5_col6 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row6_col0 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row6_col1 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row6_col2 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row6_col3 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row6_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row6_col5 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_7895b2fa_710a_11ea_aded_c4b301bdf831row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_7895b2fa_710a_11ea_aded_c4b301bdf831" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >Temperature</th>        <th class="col_heading level0 col2" >Humidity</th>        <th class="col_heading level0 col3" >Light</th>        <th class="col_heading level0 col4" >CO2</th>        <th class="col_heading level0 col5" >HumidityRatio</th>        <th class="col_heading level0 col6" >Occupancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7895b2fa_710a_11ea_aded_c4b301bdf831level0_row0" class="row_heading level0 row0" >id</th>
#                         <td id="T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col1" class="data row0 col1" >-0.442176</td>
#                         <td id="T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col2" class="data row0 col2" >0.642502</td>
#                         <td id="T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col3" class="data row0 col3" >-0.12196</td>
#                         <td id="T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col4" class="data row0 col4" >0.122284</td>
#                         <td id="T_7895b2fa_710a_11ea_aded_c4b301bdf831row0_col5" class="data row0 col5" >0.504377</td>
#                         <td id="T_7895b2fa_710a_11ea_aded_c4b301

# %%
df['Occupancy'].value_counts()
# Out:
# 0    6414
# 1    1729
# Name: Occupancy, dtype: int64

# %%
#Change all the non zero features in 1
df.loc[df['Light'] < 370, 'Light'] = 0
df.loc[df['Light'] >= 370, 'Light'] = 1

# %%
df['Light'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13335/708983098.py in <module>
# ----> 1 df['Light'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['Occupancy'].value_counts()
# Out:
# 0    6414
# 1    1729
# Name: Occupancy, dtype: int64

# %%
#Crossatab between Occupancy and light
pclass_xt = pd.crosstab(df['Light'], df['Occupancy'])
pclass_xt
# Out:
# Occupancy     0     1
# Light
# 0.0        6324    10
# 1.0          90  1719

# %%
#Create a new dataframe with only the division of date and hour
df1=pd.DataFrame({
    'date': pd.to_datetime(df['date']).dt.date,
    'time': pd.to_datetime(df['date']).dt.hour})

# %%
#Adding teh previous dataframe to the main dataframe
df['date']=df1['date']
df['Hour']=df1['time']

# %%
#The new dataframe with date and time splitted
df.head()
# Out:
#    id        date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 0   1  2015-04-02        23.18   27.2720    1.0  721.25       0.004793
# 1   2  2015-04-02        23.15   27.2675    1.0  714.00       0.004783
# 2   3  2015-04-02        23.15   27.2450    1.0  713.50       0.004779
# 3   4  2015-04-02        23.15   27.2000    1.0  708.25       0.004772
# 4   5  2015-04-02        23.10   27.2000    1.0  704.50       0.004757
#
#    Occupancy  Hour
# 0          1    17
# 1          1    17
# 2          1    17
# 3          1    17
# 4          1    17

# %%
#Adjusting the order of the column
df=df[['id', 'date', 'Hour', 'Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio', 'Occupancy']]

# %%
df.head()
# Out:
#    id        date  Hour  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 0   1  2015-04-02    17        23.18   27.2720    1.0  721.25       0.004793
# 1   2  2015-04-02    17        23.15   27.2675    1.0  714.00       0.004783
# 2   3  2015-04-02    17        23.15   27.2450    1.0  713.50       0.004779
# 3   4  2015-04-02    17        23.15   27.2000    1.0  708.25       0.004772
# 4   5  2015-04-02    17        23.10   27.2000    1.0  704.50       0.004757
#
#    Occupancy
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
#Add the column with the name of the day
df['date'] = pd.to_datetime(df['date'], format='%Y-%d-%m')

df['DayName'] = df['date'].dt.weekday_name

# %%
#Adjusting the order of the column
df=df[['id', 'date', 'DayName', 'Hour', 'Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio', 'Occupancy']]

# %%
df.head()
# Out:
#    id       date    DayName  Hour  Temperature  Humidity  Light     CO2  \
# 0   1 2015-02-04  Wednesday    17        23.18   27.2720    1.0  721.25
# 1   2 2015-02-04  Wednesday    17        23.15   27.2675    1.0  714.00
# 2   3 2015-02-04  Wednesday    17        23.15   27.2450    1.0  713.50
# 3   4 2015-02-04  Wednesday    17        23.15   27.2000    1.0  708.25
# 4   5 2015-02-04  Wednesday    17        23.10   27.2000    1.0  704.50
#
#    HumidityRatio  Occupancy
# 0       0.004793          1
# 1       0.004783          1
# 2       0.004779          1
# 3       0.004772          1
# 4       0.004757          1

# %%
#Add a new column for the boolean variable IsWorkDay, this feature is 1 if the day is a work day, 0 otherwise
df["IsWorkDay"] = np.nan
df['IsWorkDay']=df['IsWorkDay'].astype(bool).astype(int)

# %%
#Fill the feature IsWorkDay with the corrsponding 1 or 0
for index, row in df.iterrows():
    if row["DayName"]!="Saturday" and row["DayName"]!="Sunday":
        df.loc[index, "IsWorkDay"] = 1
    else:
        df.loc[index, "IsWorkDay"] = 0

# %%
#Adjusting the order of the column
df=df[['id', 'date', 'DayName', 'IsWorkDay', 'Hour', 'Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio', 'Occupancy']]

# %%
#Drop the column id because is useless for us
df.drop(['id'], axis=1, inplace =True)

# %%
#Drop the column HumidityRatio because is useless for us
df.drop(['HumidityRatio'], axis=1, inplace =True)

# %%
#Final attributes of our cleaned dataset
df.head()
# Out:
#         date    DayName  IsWorkDay  Hour  Temperature  Humidity  Light  \
# 0 2015-02-04  Wednesday          1    17        23.18   27.2720    1.0
# 1 2015-02-04  Wednesday          1    17        23.15   27.2675    1.0
# 2 2015-02-04  Wednesday          1    17        23.15   27.2450    1.0
# 3 2015-02-04  Wednesday          1    17        23.15   27.2000    1.0
# 4 2015-02-04  Wednesday          1    17        23.10   27.2000    1.0
#
#       CO2  Occupancy
# 0  721.25          1
# 1  714.00          1
# 2  713.50          1
# 3  708.25          1
# 4  704.50          1

# %%
#Add a new column for the variable IsWorkHour, this feature is 1 if the hour is a work hour,
#0 if it isn't a work hour and 2 if we have the doubt, so in the boundary values 
df["IsWorkHour"] = np.nan
df['IsWorkHour']=df['IsWorkHour'].astype(bool).astype(int)

# %%
#Fill the feature IsWorkHour with the corrsponding 0, 1 or 2
for index, row in df.iterrows():
    if row["Hour"]==13 or row["Hour"]==7 or row["Hour"]==18:
        df.loc[index, "IsWorkHour"] = 2 #could be both a work hour or not
    elif row["Hour"]<7 or row["Hour"]>18:
        df.loc[index, "IsWorkHour"] = 0 #is not a work hour
    else:
        df.loc[index, "IsWorkHour"] = 1 #is a work hour

# %%
#Adjusting the order of the column
df=df[['date', 'DayName', 'IsWorkDay', 'Hour', 'IsWorkHour', 'Temperature', 'Humidity', 'Light', 'CO2', 'Occupancy']]

# %%
#test for see if everything works
df[1300:3000]
# Out:
#            date   DayName  IsWorkDay  Hour  IsWorkHour  Temperature  Humidity  \
# 1300 2015-02-05  Thursday          1    15           1       22.500    27.600
# 1301 2015-02-05  Thursday          1    15           1       22.500    27.700
# 1302 2015-02-05  Thursday          1    15           1       22.500    27.600
# 1303 2015-02-05  Thursday          1    15           1       22.500    27.330
# 1304 2015-02-05  Thursday          1    15           1       22.550    27.445
# ...         ...       ...        ...   ...         ...          ...       ...
# 2995 2015-02-06    Friday          1    19           0       20.500    19.340
# 2996 2015-02-06    Friday          1    19           0       20.445    19.290
# 2997 2015-02-06    Friday          1    19           0       20.390    19.290
# 2998 2015-02-06    Friday          1    19           0       20.390    19.245
# 2999 2015-02-06    Friday          1    19           0       20.445    19.290
#
#       Light          CO2  Occupancy
# 1300    1.0  1085.000000          1
# 1301    1.0  1084.000000          1
# 1302    1.0  1076.250000          1
# 1303    1.0  1060.666667          1
# 1304    1.0  1051.500000          1
# ...     ...          ...        ...
# 2995    0.0   489.500000          0
# 2996    0.0   488.000000          0
# 2997    0.0   484.500000          0
# 2998    0.0   485.500000          0
# 2999    0.0   481.500000          0
#
# [1700 rows x 10 columns]

# %%
#Export the dataset cleaned
df.to_csv(r'DataCleaned.csv')

# %%
df.info()

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')

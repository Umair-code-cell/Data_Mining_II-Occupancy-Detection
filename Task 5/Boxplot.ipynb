# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from collections import defaultdict

# %%
df=pd.read_csv("../datatraining.csv", sep=";")
test=pd.read_csv("../datatest.csv", sep=";")

# %%
class_name='Occupancy'
attributes = [col for col in df.columns if 
              col == 'Temperature'
              or col == 'Humidity'
              or col == 'Light'
              or col == 'CO2'
             ]
X_train = df[attributes]
y_train = df[class_name]

X_test=test[attributes]
y_test = df[class_name]

# %%
X_trainv=X_train.values
X_testv=X_test.values

# %%
sns.boxplot(data=[X_trainv[:,0], X_trainv[:,1]])
plt.xticks([0, 1], [attributes[0], attributes[1]])
plt.show()

# %%
sns.boxplot(data=[X_trainv[:,2], X_trainv[:,3]])
plt.xticks([0, 1], [attributes[2], attributes[3]])
plt.show()

# %%
sns.boxplot(data=[X_trainv[:,0]])
plt.xticks([0], [attributes[0]])
plt.show()

# %%
sns.boxplot(data=[X_trainv[:,1]])
plt.xticks([0], [attributes[1]])
plt.show()

# %%
sns.boxplot(data=[X_trainv[:,2]])
plt.xticks([0], [attributes[2]])
plt.show()

# %%
sns.boxplot(data=[X_trainv[:,3]])
plt.xticks([0], [attributes[3]])
plt.show()
